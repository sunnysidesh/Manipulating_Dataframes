# %%
import pandas as pd
players_df = pd.read_csv('ksprojects.csv')

# %%
players_df # 65418 rows
# Out:
#                id  ...  pledged
# 0      1147015301  ...    40.00
# 1      1100844465  ...   700.00
# 2      1316334968  ...  1367.00
# 3      1304906577  ...  6575.00
# 4      1099226462  ...   501.66
# ...           ...  ...      ...
# 65413  1107492255  ...  9287.00
# 65414  1373187022  ...  5552.00
# 65415  1212504494  ...     0.00
# 65416  1347446277  ...     0.00
# 65417  1075208929  ...     0.00
#
# [65418 rows x 13 columns]

# %%
players_df.info() # Answer for Questions 2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65418 entries, 0 to 65417
# Data columns (total 13 columns):
# id               65418 non-null int64
# name             65418 non-null object
# category         65418 non-null object
# main_category    65418 non-null object
# deadline         65418 non-null object
# goal             65418 non-null float64
# launched         65418 non-null object
# state            65418 non-null object
# backers          65418 non-null int64
# country          65418 non-null object
# usd_pledged      64673 non-null float64
# currency         65418 non-null object
# pledged          65418 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 6.5+ MB

# %%
players_df.info() # Answer for Question 3 (no Null values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65418 entries, 0 to 65417
# Data columns (total 13 columns):
# id               65418 non-null int64
# name             65418 non-null object
# category         65418 non-null object
# main_category    65418 non-null object
# deadline         65418 non-null object
# goal             65418 non-null float64
# launched         65418 non-null object
# state            65418 non-null object
# backers          65418 non-null int64
# country          65418 non-null object
# usd_pledged      64673 non-null float64
# currency         65418 non-null object
# pledged          65418 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 6.5+ MB

# %%
projects_success = (players_df['state'] == 'successful') # Answer for Question 4
projects_successful = players_df.iloc[projects_success.values]
projects_successful
# Out:
#                id  ...   pledged
# 1      1100844465  ...    700.00
# 2      1316334968  ...   1367.00
# 3      1304906577  ...   6575.00
# 4      1099226462  ...    501.66
# 9      1125367305  ...   2721.00
# ...           ...  ...       ...
# 64398    11914689  ...  15985.00
# 64403  1019736572  ...   4122.12
# 64404  1238173614  ...  25708.00
# 64407  1332276657  ...  36527.00
# 64410  1130063575  ...   3175.00
#
# [23125 rows x 13 columns]

# %%
high_pl = projects_successful.sort_values(by = 'pledged', ascending = False)
high_pl.head(10)
# Out:
#                id  ...    pledged
# 12253  1033978702  ...  8596480.0
# 62904  1386523707  ...  6465690.0
# 26917  1152735261  ...  6225360.0
# 45290  1074800880  ...  5545990.0
# 46419  1045500705  ...  4079200.0
# 59897   132311747  ...  3560640.0
# 27604  1265992004  ...  3401360.0
# 63772  1118803016  ...  3215680.0
# 53611  1271291185  ...  3193360.0
# 22674   127494612  ...  3169610.0
#
# [10 rows x 13 columns]

# %%
high_pl = projects_successful.nlargest(10, columns = 'pledged')
high_pl
# Out:
#                id  ...    pledged
# 12253  1033978702  ...  8596480.0
# 62904  1386523707  ...  6465690.0
# 26917  1152735261  ...  6225360.0
# 45290  1074800880  ...  5545990.0
# 46419  1045500705  ...  4079200.0
# 59897   132311747  ...  3560640.0
# 27604  1265992004  ...  3401360.0
# 63772  1118803016  ...  3215680.0
# 53611  1271291185  ...  3193360.0
# 22674   127494612  ...  3169610.0
#
# [10 rows x 13 columns]

# %%
players_df = players_df.assign(average_per_backer = (players_df.pledged) / (players_df.backers))
players_df.head()
# Out:
#            id  ... average_per_backer
# 0  1147015301  ...          10.000000
# 1  1100844465  ...          50.000000
# 2  1316334968  ...          42.718750
# 3  1304906577  ...         273.958333
# 4  1099226462  ...          22.802727
#
# [5 rows x 14 columns]

# %%
players_df_changed = players_df.drop(['backers'], axis = 1)

# %%
import pandas as pd
airlines = pd.read_csv("airlines.csv")
flights = pd.read_csv("flights.csv")

print(airlines.columns)
print(flights.columns)
# Out:
# Index(['carrier', 'name'], dtype='object')
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')

# %%
nycflights13 = pd.merge(airlines, flights)

print(nycflights13.columns)
print(nycflights13.shape)
# Out:
# Index(['carrier', 'name', 'year', 'month', 'day', 'dep_time', 'sched_dep_time',
#        'dep_delay', 'arr_time', 'sched_arr_time', 'arr_delay', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')
# (336776, 20)

# %%
nycflights13_no_duplicates = nycflights13.drop_duplicates(['carrier'])
nycflights13_no_duplicates.shape
# Out:
# (16, 20)

# %%
import pandas as pd
census_population = pd.read_csv("state-populations.csv")
census_regions = pd.read_csv("census-divisions.csv")

print(census_population.columns)
print(census_regions.columns)
# Out:
# Index(['state', '2010', '2011', '2012', '2013', '2014', '2015', '2016'], dtype='object')
# Index(['state', 'region', 'division'], dtype='object')

# %%
census_population.reset_index(level = 0, inplace = True)

# %%
census_population.melt(id_vars = ['2010', '2011', '2012', '2013', '2014', '2015', '2016'], var_name = 'year', value_name = 'population')
# Out:
#          2010      2011      2012  ...      2016     year     population
# 0     4785492   4799918   4815960  ...   4863300  level_0              0
# 1      714031    722713    731089  ...    741894  level_0              1
# 2     6408312   6467163   6549634  ...   6931071  level_0              2
# 3     2921995   2939493   2950685  ...   2988248  level_0              3
# 4    37332685  37676861  38011074  ...  39250017  level_0              4
# ..        ...       ...       ...  ...       ...      ...            ...
# 148   8025773   8110035   8192048  ...   8411808    state       Virginia
# 149   6743226   6822520   6895226  ...   7288000    state     Washington
# 150   1854230   1854972   1856560  ...   1831102    state  West Virginia
# 151   5690263   5709640   5726177  ...   5778708    state      Wisconsin
# 152    564513    567725    576765  ...    585501    state        Wyoming
#
# [153 rows x 9 columns]

# %%
census_population.melt(id_vars = 'state', var_name = 'year', value_name = 'population')
# Out:
#              state     year  population
# 0          Alabama  level_0           0
# 1           Alaska  level_0           1
# 2          Arizona  level_0           2
# 3         Arkansas  level_0           3
# 4       California  level_0           4
# ..             ...      ...         ...
# 454       Virginia     2016     8411808
# 455     Washington     2016     7288000
# 456  West Virginia     2016     1831102
# 457      Wisconsin     2016     5778708
# 458        Wyoming     2016      585501
#
# [459 rows x 3 columns]

# %%
census = pd.merge(census_population, census_regions)

print(census.columns)
print(census.shape)
# Out:
# Index(['level_0', 'index', 'state', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', 'region', 'division'],
#       dtype='object')
# (51, 12)

# %%
census_no_duplicates = census.drop_duplicates(['state'])
census_no_duplicates
# Out:
#     level_0  index  ...     region            division
# 0         0      0  ...      South  East South Central
# 1         1      1  ...       West             Pacific
# 2         2      2  ...       West            Mountain
# 3         3      3  ...      South  West South Central
# 4         4      4  ...       West             Pacific
# 5         5      5  ...       West            Mountain
# 6         6      6  ...  Northeast         New England
# 7         7      7  ...      South      South Atlantic
# 8         8      8  ...      South      South Atlantic
# 9         9      9  ...      South      South Atlantic
# 10       10     10  ...      South      South Atlantic
# 11       11     11  ...       West             Pacific
# 12       12     12  ...       West            Mountain
# 13       13     13  ...    Midwest  East North Central
# 14       14     14  ...    Midwest  East North Central
# 15       15     15  ...    Midwest  West North Central
# ...

# %%
census_no_duplicates.groupby(['2010', '2011', '2012', '2013', '2014', '2015', '2016']).describe()
# Out:
#                                                                level_0  ... index
#                                                                  count  ...   max
# 2010     2011     2012     2013     2014     2015     2016              ...
# 564513   567725   576765   582684   583642   586555   585501       1.0  ...  50.0
# 605183   620477   635327   649165   659005   670377   681170       1.0  ...   8.0
# 625982   626730   626444   627140   626984   626088   624594       1.0  ...  45.0
# 674526   685476   702087   724019   739904   756835   757952       1.0  ...  34.0
# 714031   722713   731089   736879   736705   737709   741894       1.0  ...   1.0
# 816325   824398   834441   844922   852561   857919   865454       1.0  ...  41.0
# 899816   907924   916993   925395   934948   944076   952065       1.0  ...   7.0
# 990641   997821   1005196  1014314  1022867  1032073  1042520      1.0  ...  26.0
# ...

# %%
census_no_duplicates
